# %%
import pandas as pd

# %%
dataset=pd.read_csv("D:\Data_Sets\Brain Stroke.csv")

# %%
dataset
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
# ...

# %%
dataset.loc[(dataset['gender']=="Male") & (dataset['Residence_type']=="Urban") & (dataset['bmi']<30)]
# Out:
#      gender   age  hypertension  heart_disease ever_married      work_type  \
# 4      Male  81.0             0              0          Yes        Private
# 14     Male  75.0             1              0          Yes        Private
# 20     Male  71.0             0              0          Yes        Private
# 23     Male  69.0             0              1          Yes  Self-employed
# 28     Male  48.0             0              0           No       Govt_job
# ...     ...   ...           ...            ...          ...            ...
# 4933   Male  67.0             0              0          Yes        Private
# 4942   Male  34.0             0              0          Yes        Private
# 4946   Male   1.8             0              0           No       children
# 4952   Male   8.0             0              0           No       children
# 4956   Male  31.0             0              0          Yes        Private
#
# ...

# %%
dataset["Residence_type"].unique()
# Out:
# array(['Urban', 'Rural'], dtype=object)

# %%
dataset["Residence_type"].value_counts()
# Out:
# Urban    2532
# Rural    2449
# Name: Residence_type, dtype: int64

# %%
dataset["work_type"].unique()
# Out:
# array(['Private', 'Self-employed', 'Govt_job', 'children'], dtype=object)

# %%
dataset["work_type"].value_counts()
# Out:
# Private          2860
# Self-employed     804
# children          673
# Govt_job          644
# Name: work_type, dtype: int64

# %%
dataset.loc[(dataset['gender']=="Male") & (dataset['Residence_type']=="Urban") & (dataset['bmi']<30),["gender","age","work_type","Residence_type"]]
# Out:
#      gender   age      work_type Residence_type
# 4      Male  81.0        Private          Urban
# 14     Male  75.0        Private          Urban
# 20     Male  71.0        Private          Urban
# 23     Male  69.0  Self-employed          Urban
# 28     Male  48.0       Govt_job          Urban
# ...     ...   ...            ...            ...
# 4933   Male  67.0        Private          Urban
# 4942   Male  34.0        Private          Urban
# 4946   Male   1.8       children          Urban
# 4952   Male   8.0       children          Urban
# 4956   Male  31.0        Private          Urban
#
# [630 rows x 4 columns]

# %%
dataset.loc[(dataset['gender']=="Male") & (dataset['Residence_type']=="Urban") & (dataset['bmi']<30),"heart_disease":"Residence_type"]
# Out:
#       heart_disease ever_married      work_type Residence_type
# 4                 0          Yes        Private          Urban
# 14                0          Yes        Private          Urban
# 20                0          Yes        Private          Urban
# 23                1          Yes  Self-employed          Urban
# 28                0           No       Govt_job          Urban
# ...             ...          ...            ...            ...
# 4933              0          Yes        Private          Urban
# 4942              0          Yes        Private          Urban
# 4946              0           No       children          Urban
# 4952              0           No       children          Urban
# 4956              0          Yes        Private          Urban
#
# [630 rows x 4 columns]
