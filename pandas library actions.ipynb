# %%
import pandas as pd

# %%
dataset=pd.read_csv("D:\Data_Sets\Brain Stroke.csv")

# %%
dataset
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
# ...

# %%
ap=[]
for x in dataset["age"]:
    p=x+2
    ap.append(p)
print(ap)
# Out:
# [69.0, 82.0, 51.0, 81.0, 83.0, 76.0, 71.0, 80.0, 83.0, 63.0, 56.0, 81.0, 52.0, 66.0, 77.0, 62.0, 73.0, 54.0, 81.0, 84.0, 73.0, 82.0, 67.0, 71.0, 59.0, 44.0, 84.0, 82.0, 50.0, 84.0, 76.0, 74.0, 60.0, 51.0, 80.0, 56.0, 84.0, 62.0, 78.0, 60.0, 83.0, 41.0, 81.0, 79.0, 65.0, 84.0, 75.0, 56.0, 58.0, 82.0, 69.0, 47.0, 80.0, 72.0, 78.0, 61.0, 82.0, 69.0, 68.0, 65.0, 54.0, 82.0, 82.0, 81.0, 45.0, 61.0, 81.0, 70.0, 56.0, 63.0, 72.0, 49.0, 76.0, 81.0, 83.0, 59.0, 82.0, 47.0, 80.0, 72.0, 60.0, 59.0, 71.0, 66.0, 79.0, 76.0, 83.0, 59.0, 52.0, 56.0, 81.0, 55.0, 81.0, 82.0, 70.0, 73.0, 63.0, 76.0, 40.0, 79.0, 60.0, 55.0, 82.0, 58.0, 74.0, 82.0, 84.0, 75.0, 80.0, 71.0, 70.0, 73.0, 78.0, 78.0, 78.0, 77.0, 84.0, 61.0, 76.0, 71.0, 74.0, 68.0, 80.0, 59.0, 72.0, 70.0, 82.0, 70.0, 57.0, 79.0, 52.0, 59.0, 73.0, 83.0, 80.0, 72.0, 80.0, 58.0, 81.0, 83.0, 62.0, 82.0, 74.0, 82.0, 80.0, 83.0, 48.0, 61.0, 34.0, 63.0, 65.0, 65.0, 84.0, 84.0, 67.0, 53.0, 61.0, 70.0, 74.0, 61.0, 72.0, 71.0, 76.0, 82.0, 79.0, 80.0, 5
# ...

# %%
dataset.insert(2,"updated_age",ap)

# %%
dataset
# Out:
#       gender   age  updated_age  hypertension  heart_disease ever_married  \
# 0       Male  67.0         69.0             0              1          Yes
# 1       Male  80.0         82.0             0              1          Yes
# 2     Female  49.0         51.0             0              0          Yes
# 3     Female  79.0         81.0             1              0          Yes
# 4       Male  81.0         83.0             0              0          Yes
# ...      ...   ...          ...           ...            ...          ...
# 4976    Male  41.0         43.0             0              0           No
# 4977    Male  40.0         42.0             0              0          Yes
# 4978  Female  45.0         47.0             1              0          Yes
# 4979    Male  40.0         42.0             0              0          Yes
# 4980  Female  80.0         82.0             1              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
del dataset["age"]

# %%
dataset
# Out:
#       gender  updated_age  hypertension  heart_disease ever_married  \
# 0       Male         69.0             0              1          Yes
# 1       Male         82.0             0              1          Yes
# 2     Female         51.0             0              0          Yes
# 3     Female         81.0             1              0          Yes
# 4       Male         83.0             0              0          Yes
# ...      ...          ...           ...            ...          ...
# 4976    Male         43.0             0              0           No
# 4977    Male         42.0             0              0          Yes
# 4978  Female         47.0             1              0          Yes
# 4979    Male         42.0             0              0          Yes
# 4980  Female         82.0             1              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
dataset["smoking_status"].unique()
# Out:
# array(['formerly smoked', 'never smoked', 'smokes', 'Unknown'],
#       dtype=object)

# %%
dataset.loc[(dataset['gender']=="Male") & (dataset['hypertension']==1) & (dataset['heart_disease']==1) & (dataset['ever_married']=="Yes")& (dataset['work_type']=="Govt_job")]
# Out:
#      gender  updated_age  hypertension  heart_disease ever_married work_type  \
# 333    Male         55.0             1              1          Yes  Govt_job
# 755    Male         63.0             1              1          Yes  Govt_job
# 2767   Male         61.0             1              1          Yes  Govt_job
# 3613   Male         83.0             1              1          Yes  Govt_job
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 333           Rural             109.51  41.9     never smoked       0
# 755           Rural              86.06  34.8     never smoked       0
# 2767          Rural              81.51  32.6     never smoked       0
# 3613          Rural             217.94  24.1  formerly smoked       0

# %%
dataset
# Out:
#       gender  updated_age  hypertension  heart_disease ever_married  \
# 0       Male         69.0             0              1          Yes
# 1       Male         82.0             0              1          Yes
# 2     Female         51.0             0              0          Yes
# 3     Female         81.0             1              0          Yes
# 4       Male         83.0             0              0          Yes
# ...      ...          ...           ...            ...          ...
# 4976    Male         43.0             0              0           No
# 4977    Male         42.0             0              0          Yes
# 4978  Female         47.0             1              0          Yes
# 4979    Male         42.0             0              0          Yes
# 4980  Female         82.0             1              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
dataset.loc[(dataset['gender']=="Female") & (dataset['updated_age']>=40) & (dataset['hypertension']==1) & (dataset['heart_disease']==1) & (dataset['ever_married']=="Yes") & (dataset['Residence_type']=="Urban") & (dataset['avg_glucose_level']>=100) & (dataset['avg_glucose_level']<=230)]
# Out:
#       gender  updated_age  hypertension  heart_disease ever_married  \
# 152   Female         84.0             1              1          Yes
# 179   Female         57.0             1              1          Yes
# 303   Female         81.0             1              1          Yes
# 1597  Female         80.0             1              1          Yes
# 1714  Female         55.0             1              1          Yes
# 2848  Female         62.0             1              1          Yes
# 3335  Female         74.0             1              1          Yes
# 3715  Female         74.0             1              1          Yes
# 4285  Female         84.0             1              1          Yes
# 4817  Female         78.0             1              1          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 152        Govt_job          Urban             215.94  27.9  formerly smoked
# ...
